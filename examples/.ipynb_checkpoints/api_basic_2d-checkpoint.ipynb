# %% [markdown]
# # Basic API for qttpdesolver package (2D case).
#
# For illustration, we consider below the following solvers
#
# - Solver-FS (a new Finite Sum solver)
#
# - Solver-FD (a Finite Difference solver)
#
# for 2D stationary diffusion type PDE with scalar coefficient.
#
# <h3 style="color:green; padding-left: 20px;">See <b>api_basic_1d</b> file with detailed API description.</h3>

# %%
# %matplotlib inline
import numpy as np

from qttpdesolver import Pde, auto_solve, Func
from qttpdesolver import MODE_NP, MODE_TT, MODE_SP, SOLVER_FS, SOLVER_FD, BC_HD, BC_PR

# %%
PDE = Pde(txt='Simple 2D PDE for test', dim=2) 

def f_func(x, y, w1, w2):
    xy = x*y; xy2 = xy*y
    s1 = np.sin(w1*x*x); s2 = np.sin(w2*y)
    c1 = np.cos(w1*x*x); c2 = np.cos(w2*y)
    return (4.*w1*w1*x*x + w2*w2)*(1. +xy2)*s1*s2\
          - 2.*w1*(1. + 2.*xy2)*c1*s2 - 2.*w2*xy*s1*c2

PDE.Kx  = Func(2, 'kx', '1+x*y^2').set_expr('1. + x*y*y')
PDE.Ky  = Func(2, 'ky', '1+x*y^2').set_expr('1. + x*y*y')
PDE.F   = Func(2, 'f', '... according to exact solution u').set_func(f_func)
PDE.U   = Func(2, 'u_real', 'sin(w_1 x^2) sin(w_2 y)').set_expr('np.sin(w1*x*x) * np.sin(w2*y)')
PDE.Ux  = Func(2, 'ux_real', '2 w_1 x cos(w_1 x^2) sin(w_2 y)').set_expr('w1*2.*x*np.cos(w1*x*x)*np.sin(w2*y)') 
PDE.Uy  = Func(2, 'uy_real', 'w_2 sin(w_1 x^2) cos(w_2 y)').set_expr('w2*np.sin(w1*x*x)*np.cos(w2*y)')
PDE.set_params([np.pi/PDE.L * 2, np.pi/PDE.L * 3], ['w1', 'w2'], ['%-8.4f', '%-8.4f']) 
PDE.present_model()

#We can use a model from the gallery instead:
#PDE.present_models()
#PDE.set_model('divkgrad_2d_hd_analyt')
#PDE.set_params([np.pi/PDE.L * 2, np.pi/PDE.L * 3])
# Out:
# PDE        : Simple 2D PDE for test
# Parameters : w1=6.2832  ; w2=9.4248
# BC         : hd
# kx         = 1+x*y^2
# ky         = 1+x*y^2
# f          = ... according to exact solution u
# u_real     = sin(w_1 x^2) sin(w_2 y)
# ux_real    = 2 w_1 x cos(w_1 x^2) sin(w_2 y)
# uy_real    = w_2 sin(w_1 x^2) cos(w_2 y)

# %%
PDE.set_mode(MODE_TT)
PDE.set_solver_name(SOLVER_FS)
PDE.set_verb(verb_gen=True, verb_crs=False, verb_lss=True)
PDE.set_tau(tau=1.E-10, eps_lss=1.E-10, tau_lss=1.E-10)
PDE.set_lss_params(nswp=20, kickrank=4, local_prec='n', local_iters=2, 
                   local_restart=20, trunc_norm=1, max_full_size=100)
PDE.present_info()
# Out:
# __________________General parameters
# Mode          : tt
# Solver        : fs
# Boundary cond.: hd
# Parameters    : w1=6.2832  ; w2=9.4248
# __________________Verbosity parameters
# verb_gen      : True
# verb_crs      : False
# verb_lss      : True
# print_to_std  : True
# print_to_file : False
# __________________TT parameters
# tau                : 1.00e-10
# eps_lss            : 1.00e-10
# tau_lss            : 1.00e-10
# tau_real           : 1.00e-12
# lss> nswp          : 20
# lss> kickrank      : 4
# lss> max full size : 100
# lss> local restart : 20
# lss> local iters   : 2
# lss> use sol0      : False

# %%
PDESolver = auto_solve(PDE, d=6, return_solver=True)
# Out:
# Time of coeffs.  generation: 0.1719
# Time of matrices generation: 0.0664
# Time of system generation  : 0.0257
# amen_solve: swp=1, max_dx= 9.719E-01, max_res= 9.716E-01, max_rank=18
# amen_solve: swp=2, max_dx= 9.733E-08, max_res= 1.274E-08, max_rank=22
# amen_solve: swp=3, max_dx= 4.993E-09, max_res= 2.209E-10, max_rank=23
# amen_solve: swp=4, max_dx= 1.184E-10, max_res= 4.322E-11, max_rank=24
# Time of system solving     : 0.3291
# Time of additional calcs.  : 0.1849
# d= 6|fs-tt|hd|er=1.8e-03 |erdx=1.0e-03 |erdy=9.3e-04 |T=   0.593|R=   8.4|It= 4

# %%
PDE.present_res()
PDE.plot_res()
# Out:
# PDE                : Simple 2D PDE for test
# PDE mode           : tt
# Used PDE solver    : fs
# Boundary condition : hd
# PDE dimension      : 2
# Value of d         : 6
# Mesh 1D size       : 64
# Solution erank     : 8.40
# Analit. sol. erank : 3.13
# Solution error     : 1.79e-03
# X-derivative error : 1.03e-03
# Y-derivative error : 9.28e-04
# (u, f) real        : 38.2537061675
# (u, f) calc        : 38.3246078468
# (u, f) err         : 1.85e-03
# Solver iterations  : 4
# Matrix A erank     : 30
# Vector rhs erank   : 9
# Time: coeff.   (s.): 0.1719
# Time: matrices (s.): 0.0664
# Time: system   (s.): 0.0257
# Time: system   (s.): 0.3291
# Total time     (s.): 0.5932
# *Time: prep.   (s.): 0.1849

# %% [markdown]
# ### The following important variables and values are saved in Pde class instance after calculation (some of them may be None)

# %%
print PDE.u_calc
print PDE.u_real
print PDE.ux_calc
print PDE.ux_real
print PDE.uy_calc
print PDE.uy_real
print PDE.uu_calc
print PDE.uf_calc
# Out:
# > tt-vector |u_calc|             [tau=1.00e-10] {d =12} (erank =  8.4)
# > tt-vector |u_real|             [tau=1.00e-10] {d =12} (erank =  3.1)
# > tt-vector |ux_calc|            [tau=1.00e-10] {d =12} (erank = 10.3)
# > tt-vector |ux_real|            [tau=1.00e-10] {d =12} (erank =  3.1)
# > tt-vector |uy_calc|            [tau=1.00e-10] {d =12} (erank =  9.7)
# > tt-vector |uy_real|            [tau=1.00e-10] {d =12} (erank =  3.1)
# 0.20691374665
# 38.3246078468

# %% [markdown]
# ### The following variables are saved in PDESolver class instance (for Solver_FS) after calculation

# %%
print PDESolver.f
print PDESolver.iKx
print PDESolver.iKy
print PDESolver.Bx
print PDESolver.By
print PDESolver.iqx
print PDESolver.iqy
print PDESolver.qx
print PDESolver.qy
print PDESolver.Wx
print PDESolver.Wy
print PDESolver.Rx
print PDESolver.Ry
print PDESolver.Hx
print PDESolver.Hy
print PDESolver.A
print PDESolver.rhs
print PDESolver.wx
# Out:
# > tt-vector |f|                  [tau=1.00e-10] {d =12} (erank =  5.6)
# > tt-matrix |iKx|                [tau=1.00e-10] {d =12} (erank =  7.0)
# > tt-matrix |iKy|                [tau=1.00e-10] {d =12} (erank =  7.0)
# > tt-matrix |Bx|                 [tau=1.00e-10] {d =12} (erank =  1.5)
# > tt-matrix |By|                 [tau=1.00e-10] {d =12} (erank =  1.5)
# > tt-vector |iqx|                [tau=1.00e-10] {d = 6} (erank =  3.6)
# > tt-vector |iqy|                [tau=1.00e-10] {d = 6} (erank =  3.4)
# > tt-vector |qx|                 [tau=1.00e-10] {d = 6} (erank =  3.6)
# > tt-vector |qy|                 [tau=1.00e-10] {d = 6} (erank =  3.4)
# > tt-matrix |Wx|                 [tau=1.00e-10] {d =12} (erank =  2.5)
# > tt-matrix |Wy|                 [tau=1.00e-10] {d =12} (erank =  2.3)
# > tt-matrix |Rx|                 [tau=1.00e-10] {d =12} (erank = 14.7)
# > tt-matrix |Ry|                 [tau=1.00e-10] {d =12} (erank = 23.7)
# > tt-matrix |Hx|                 [tau=1.00e-10] {d =12} (erank = 15.3)
# > tt-matrix |Hy|                 [tau=1.00e-10] {d =12} (erank = 23.7)
# > tt-matrix |A|                  [tau=1.00e-10] {d =12} (erank = 30.6)
# > tt-vector |rhs|                [tau=1.00e-10] {d =12} (erank =  9.0)
# > tt-vector |wx_calc|            [tau=1.00e-10] {d =12} (erank = 10.6)

# %% [markdown]
# ### Note that all variables have type Vector or Matrix from subpackage tensor_wrapper.
#
# This is format-free representation of arrays (operations in MODE_NP, MODE_TT and MODE_SP have the same form in this format).
#
# If one needs numpy array, then to_np property should be called (it works only for moderate d values).
#
# Property to_tt converts Vector or Matrix class instance to tt-format.
#
# Otherwise the .x property may be used - it contains the np.ndarray or tt.vector or tt.matrix or scipy.sparse scr matrix.

# %%
print type(PDESolver.A)
A_tt = PDESolver.A.to_tt
print type(A_tt)
A_np = PDESolver.A.to_np
print type(A_np)
print A_np.shape
print type(PDESolver.A.x)
# Out:
# <class 'qttpdesolver.tensor_wrapper.matrix.Matrix'>
# <class 'tt.core.matrix.matrix'>
# <type 'numpy.ndarray'>
# (4096, 4096)
# <class 'tt.core.matrix.matrix'>
